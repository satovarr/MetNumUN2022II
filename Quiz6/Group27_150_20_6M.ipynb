# %% [markdown]
# <a href="https://colab.research.google.com/github/Feliperojas2601/MetNumUN2022II/blob/main/Quiz6/Group27_150_20_6M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Group27_150_20_6M

# %%
import xarray as xr

import qnt.ta as qnta
import qnt.data as qndata
import qnt.output as qnout
import qnt.stats as qns

# 6 months - 150/20 days

data = qndata.stocks.load_ndx_data(min_date="2022-04-10")

close     = data.sel(field="close")
is_liquid = data.sel(field="is_liquid")
sma_slow  = qnta.sma(close, 150)
sma_fast  = qnta.sma(close, 20)
weights   = xr.where(sma_slow < sma_fast, 1, -1)
weights   = weights * is_liquid

weights = qnout.clean(weights, data, "stocks_nasdaq100")

# calc stats
stats = qns.calc_stat(data, weights.sel(time=slice("2022-04-10", None)))
display(stats.to_pandas().tail())

# graph
performance = stats.to_pandas()["equity"]
import qnt.graph as qngraph

qngraph.make_plot_filled(performance.index, performance, name="PnL (Equity)", type="log")
# Out:
# fetched chunk 1/1 0s
# Data loaded 0s
# Output cleaning...
# fix uniq
# ffill if the current price is None...
# Check liquidity...
# Ok.
# Check missed dates...
# Ok.
# Normalization...
# Output cleaning is complete.
# field         equity  relative_return  volatility  underwater  max_drawdown  \
# time
# 2022-09-30  1.085861         0.014040    0.301261   -0.021208     -0.187871
# 2022-10-03  1.057396        -0.026215    0.302518   -0.046867     -0.187871
# 2022-10-04  1.020246        -0.035133    0.305579   -0.080353     -0.187871
# 2022-10-05  1.019871        -0.000368    0.304336   -0.080692     -0.187871
# 2022-10-06  1.029579         0.009519    0.303385   -0.071941     -0.187871
#
# field       sharpe_ratio  mean_return  bias  instruments  avg_turnover  \
# time
# 2022-09-30      0.624149     0.188032  -1.0        102.0      0.036496
# 2022-10-03      0.405716     0.122737  -1.0        102.0      0.036412
# ...

# %%
weights = weights.sel(time=slice("2022-04-10",None))

qnout.check(weights, data, "stocks_nasdaq100")
qnout.write(weights) # to participate in the competition
# Out:
# Check liquidity...
# Ok.
# Check missed dates...
# Ok.
# Check the sharpe ratio...
# WARNING! There are not enough points in the data
# The first point(2022-04-11) should be earlier than 2006-01-01
# Load data more historical data.
# WARNING! There are not enough points in the output.
# The output series should start from 2006-01-01 or earlier instead of 2022-04-11
# Period: 2022-04-11 - 2022-10-06
# Sharpe Ratio = 0.20076577467416873
# ERROR! The Sharpe Ratio is too low. 0.20076577467416873 < 1
# Improve the strategy and make sure that the in-sample Sharpe Ratio more than 1.
# Check correlation.
#
# Ok. This strategy does not correlate with other strategies.
# Write output: /root/fractions.nc.gz
